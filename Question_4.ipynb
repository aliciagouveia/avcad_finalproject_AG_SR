# %%
### Question 4

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
file_path = "Registos_Incendios_SGIF_2011_2020.xlsx"
data = pd.read_excel(file_path)

# Display the first few rows of the dataset and check columns
print(data.head())

# Count fires per district
fires_per_district = data['Distrito'].value_counts().reset_index()
fires_per_district.columns = ['Distrito', 'Num_Fires']
fires_per_district = fires_per_district.sort_values(by='Num_Fires', ascending=False)

# Plotting
plt.figure(figsize=(12, 8))
sns.barplot(data=fires_per_district, x='Distrito', y='Num_Fires', palette='Oranges_r')
plt.xticks(rotation=90)
plt.xlabel('District')
plt.ylabel('Number of Fires')
plt.title('Distribution of Fires per District (2011-2020)')
plt.tight_layout()
plt.show()

# Print the district with the most fires
district_most_fires = fires_per_district.iloc[0]['Distrito']
num_most_fires = fires_per_district.iloc[0]['Num_Fires']
print(f"The district with the most fires is {district_most_fires} with {num_most_fires} fires.")
# Out:
#   Codigo_SGIF  Codigo_ANEPC   Ano  Mes  Dia  Hora  AreaPov_ha  AreaMato_ha  \
# 0      DM2111           368  2011    1    1    17         0.0        0.010
# 1      BL4112          1236  2011    1    9    22         0.0        0.000
# 2      DM3111           820  2011    1   15    17         0.0        0.000
# 3      BL2111          1977  2011    1   18    22         0.0        0.001
# 4      DM2113          7930  2011    1   19    17         0.0        0.005
#
#    AreaAgric_ha  AreaTotal_ha  ...       ISI         DC       DMC       FFMC  \
# 0       0.00000       0.01000  ...  0.291930   4.092373  0.653638  54.525424
# 1       0.00200       0.00200  ...  0.013831   1.835452  0.367371  32.001278
# 2       0.00001       0.00001  ...  1.171990   9.658571  1.573768  74.889775
# 3       0.00000       0.00100  ...  0.248910  12.477199  0.762519  51.102608
# 4       0.00000       0.00500  ...  0.008092   3.968661  0.508191  32.290416
#
#         BUI  CodCausa     TipoCausa  \
# ...
