# %% [markdown]
# ## Question 1

# %% [markdown]
# Import Dataset

# %%
#Import the dataset
import pandas as pd

# Load the data
file_path = 'Registos_Incendios_SGIF_2011_2020.xlsx'
df = pd.read_excel(file_path)

print(df.head())
# Out:
#   Codigo_SGIF  Codigo_ANEPC   Ano  Mes  Dia  Hora  AreaPov_ha  AreaMato_ha  \
# 0      DM2111           368  2011    1    1    17         0.0        0.010
# 1      BL4112          1236  2011    1    9    22         0.0        0.000
# 2      DM3111           820  2011    1   15    17         0.0        0.000
# 3      BL2111          1977  2011    1   18    22         0.0        0.001
# 4      DM2113          7930  2011    1   19    17         0.0        0.005
#
#    AreaAgric_ha  AreaTotal_ha  ...       ISI         DC       DMC       FFMC  \
# 0       0.00000       0.01000  ...  0.291930   4.092373  0.653638  54.525424
# 1       0.00200       0.00200  ...  0.013831   1.835452  0.367371  32.001278
# 2       0.00001       0.00001  ...  1.171990   9.658571  1.573768  74.889775
# 3       0.00000       0.00100  ...  0.248910  12.477199  0.762519  51.102608
# 4       0.00000       0.00500  ...  0.008092   3.968661  0.508191  32.290416
#
#         BUI  CodCausa     TipoCausa  \
# 0  0.934234     145.0    Negligente
# 1  0.489703     610.0  Desconhecida
# 2  2.236498     124.0    Negligente
# 3  1.322920     124.0    Negligente
# 4  0.769912       NaN           NaN
#
#                                           GrupoCausa  \
# 0                            Uso do fogo - Fogueiras
# 1                                     Indeterminadas
# 2  Queimas amontoados de sobrantes florestais ou ...
# 3  Queimas amontoados de sobrantes florestais ou ...
# 4                                                NaN
#
#                         DescricaoCausa FonteAlerta
# 0                   Fogueiras - Outras   Populares
# 1      Indeterminadas - Prova material   Populares
# 2  Queima de amontoados - Borralheiras   Populares
# 3  Queima de amontoados - Borralheiras   Populares
# 4                                  NaN   Populares
#
# [5 rows x 41 columns]

# %% [markdown]
# How do fire occurrences vary across different months and years?

# %%
#Fire Ocurrences per Year
import matplotlib.pyplot as plt

#Count the number of fires per year
fires_per_year = df.groupby('Ano').size()

#Extract all unique years from the dataset
years = df['Ano'].unique()

#Plot the fires per year
plt.figure(figsize=(10, 6))
fires_per_year.plot(kind='line', marker='o', linestyle='-', color='orange')
plt.xlabel('Year')
plt.ylabel('Number of Fire Occurrences')
plt.title('Number of Fire Occurrences per Year')
plt.xticks(ticks=years)
plt.grid(True)
plt.show()

# %%
#Fire Ocurrences per month in a certain year
import matplotlib.pyplot as plt
import calendar

# Define a specific year to analyze
specific_year = 2020

# Filter data for the specific year
df_specific_year = df[df['Ano'] == specific_year]

# Count the number of fire occurrences per month for the specific year
fires_per_month_specific_year = df_specific_year['Mes'].value_counts().sort_index()

# Ensure all months (1 to 12) are included
all_months = range(1, 13)
fires_per_month_specific_year = fires_per_month_specific_year.reindex(all_months, fill_value=0)

# Get month names
month_names = [calendar.month_name[i] for i in all_months]

# Plot the number of fire occurrences per month for the specific year using a line plot
plt.figure(figsize=(10, 6))
fires_per_month_specific_year.plot(kind='line', marker='o', linestyle='-', color='orange')
plt.xlabel('Month')
plt.ylabel('Number of Fire Occurrences')
plt.title(f'Number of Fire Occurrences per Month in {specific_year}')
plt.xticks(ticks=all_months, labels=month_names, rotation=45)
plt.grid(True)
plt.show()

# %% [markdown]
# Are there certain months or seasons with higher fire occurrences?

# %%
#Fire Occurrences per month for all the years
import matplotlib.pyplot as plt
import calendar

# Pivot the table to get months as columns and years as rows
fires_per_month_year = df.pivot_table(index='Ano', columns='Mes', values='Codigo_SGIF', aggfunc='size', fill_value=0)

# Get month names
month_names = [calendar.month_name[i] for i in range(1, 13)]

# Plot the number of fire occurrences per month for each year
plt.figure(figsize=(14, 8))

for year in fires_per_month_year.index:
    plt.plot(month_names, fires_per_month_year.loc[year], marker='o', linestyle='-', label=year)

plt.xlabel('Month')
plt.ylabel('Number of Fire Occurrences')
plt.title('Number of Fire Occurrences per Month for Each Year')
plt.legend(title='Year')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
#Fire Occurrences per month for all the years (Interactive plot)
import plotly.graph_objects as go
import calendar

# Pivot the table to get months as columns and years as rows
fires_per_month_year = df.pivot_table(index='Ano', columns='Mes', values='Codigo_SGIF', aggfunc='size', fill_value=0)

# Get month names
month_names = [calendar.month_name[i] for i in range(1, 13)]

# Create an interactive plot
fig = go.Figure()

for year in fires_per_month_year.index:
    fig.add_trace(go.Scatter(
        x=month_names,
        y=fires_per_month_year.loc[year],
        mode='lines+markers',
        name=str(year)
    ))

fig.update_layout(
    title='Number of Fire Occurrences per Month for Each Year',
    xaxis_title='Month',
    yaxis_title='Number of Fire Occurrences',
    xaxis=dict(tickmode='array', tickvals=month_names),
    yaxis=dict(rangemode='tozero'),
    legend_title='Year',
    hovermode='x unified'
)

fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.32.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="c376f191-6db3-401f-9e35-1de61efa9f5d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c376f191-6db3-401f-9e35-1de61efa9f5d")) {                    Plotly.newPlot(                        "c376f191-6db3-401f-9e35-1de61efa9f5d",                        [{"mode":"lines+markers","name":"2011","x":["January","February","March","April","May","June","July","August","September","October","November","December"],"y":[269,429,1179,1313,903,3577,5271,4709,3084,8695,130,223],"type":"scatter"},{"mode":"lines+markers","name":"2012","x":["January","February","March","April","May","June","July","August","September","October","November","December"],"y":[388,4370,4728,994,660,1180,3419,3332,5357,837,64,23],"type":"scatter"},{"mode":"lines+markers","name":"2013","x":["January","February","March","April","May","June","July","August","September","October","November","December"],"y":[25,111,219,790,1067,2282,4011,7609,5363,539,466,647],"type":"scatter"},{"mode":"lines+markers","name":"2014","x":["January","February","March","April","May","June","July","August","September","October","November","December"],"y":[13,6,697,388,1433,1274,1726,2343,970,464,40,34],"type":"scatter"},{"mode":"lines+markers","name":"2015","x":["January","February","March","April","May","June","July","August","September","October","November","December"],"y":[229,303,2211,1532,1669,2279,3801,4010,2296,839,208,266],"type":"scatter"},{"mode":"lines+markers","name":"2016","x":["January","February","March","April","May","June","July","August","September","October","November","December"],"y":[11,81,278,346,434,896,3543,5353,3053,1512,333,264],"type":"scatter"},{"mode":"lines+markers","name":"2017","x":["January","February","March","April","May","June","July","August","September","October","November","December"],"y":[795,318,1270,2498,930,1871,2457,4227,2262,3234,822,322],"type":"scatter"},{"mode":"lines+markers","name":"2018","x":["January","February","March","April","May","June","July","August","September","October","November","December"],"y":[149,1444,201,1056,2085,583,757,2250,1818,1818,57,56],"type":"scatter"},{"mode":"lines+markers","name":"2019","x":["January","February","March","April","May","June","July","August","September","October","November","December"],"y":[405,480,1255,216,1216,1140,1496,1591,2215,720,56,42],"type":"scatter"},{"mode":"lines+markers","name":"2020","x":["January","February","March","April","May","June","July","August","September","October","November","December"],"y":[69,140,319,86,469,891,3047,1882,1808,769,120,19],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953 ...

# %% [markdown]
# Can we identify what were the larger fires?

# %%
#Large fires for a certain year
import pandas as pd
import matplotlib.pyplot as plt

# Specify the year
specific_year = 2017

# Filter the dataset for the specific year
df_specific_year = df[df['Ano'] == specific_year]

# Determine a threshold for large fires (e.g., top 10% of burned area in the specific year)
threshold = df_specific_year['AreaTotal_ha'].quantile(0.90)

# Filter the dataset for large fires in the specific year
large_fires = df_specific_year[df_specific_year['AreaTotal_ha'] > threshold]

# Display the threshold value
print(f'Threshold for large fires in {specific_year} (top 10%): {threshold} hectares')

# Scatter plot of large fires in the specific year with months on x-axis
plt.figure(figsize=(10, 6))
plt.scatter(large_fires['Mes'], large_fires['AreaTotal_ha'], color='orange', alpha=0.6, edgecolors='w', s=70)
plt.xlabel('Month')
plt.ylabel('Total Burned Area (hectares)')
plt.title(f'Large Fires by Month in {specific_year}')
plt.xticks(ticks=range(1, 13), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.grid(True)
plt.show()
# Out:
# Threshold for large fires in 2017 (top 10%): 3.0 hectares
